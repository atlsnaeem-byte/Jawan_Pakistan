# %% [markdown]
# ## list Comprehension

# %%
Ec_Store_Orders = [
    {"order_id": 1, "customer_name": "Ali", "total_amount": 120, "status": "Completed"},
    {"order_id": 2, "customer_name": "Raheel", "total_amount": 80, "status": "Pending"},
    {"order_id": 3, "customer_name": "Saleem", "total_amount": 150, "status": "Completed"},
    {"order_id": 4, "customer_name": "khushnoor", "total_amount": 95, "status": "Completed"},
    {"order_id": 5, "customer_name": "Alizy", "total_amount": 200, "status": "Pending"},
    {"order_id": 6, "customer_name": "javaid", "total_amount": 85, "status": "Completed"},
    {"order_id": 7, "customer_name": "Talha", "total_amount": 150, "status": "Pending"},
    {"order_id": 8, "customer_name": "Naveed", "total_amount": 200, "status": "Completed"},
]

# %% [markdown]
# #### Write a Python program to create a list of "order_ids" for all orders where the total_amount is greater than 100 and the order status is "Completed".

# %%
for order in Ec_Store_Orders:
    print(order)
# Out:
# {'order_id': 1, 'customer_name': 'Ali', 'total_amount': 120, 'status': 'Completed'}
# {'order_id': 2, 'customer_name': 'Raheel', 'total_amount': 80, 'status': 'Pending'}
# {'order_id': 3, 'customer_name': 'Saleem', 'total_amount': 150, 'status': 'Completed'}
# {'order_id': 4, 'customer_name': 'khushnoor', 'total_amount': 95, 'status': 'Completed'}
# {'order_id': 5, 'customer_name': 'Alizy', 'total_amount': 200, 'status': 'Pending'}
# {'order_id': 6, 'customer_name': 'javaid', 'total_amount': 85, 'status': 'Completed'}
# {'order_id': 7, 'customer_name': 'Talha', 'total_amount': 150, 'status': 'Pending'}
# {'order_id': 8, 'customer_name': 'Naveed', 'total_amount': 200, 'status': 'Completed'}

# %%
order_ids = []

for order in Ec_Store_Orders:
    if order['total_amount'] > 100 and order['status'] == 'Completed':
        order_ids.append(order['order_id'])
order_ids
# Out:
# [1, 3, 8]

# %%
order_ids
# Out:
# [1, 3, 8]

# %%
order_ids1 = [order['order_id'] for order in Ec_Store_Orders if order['total_amount'] > 100 and order['status'] == 'Completed']

# %%
order_ids1
# Out:
# [1, 3, 8]

# %%
Ec_Store_Orders
# Out:
# [{'order_id': 1,
#   'customer_name': 'Ali',
#   'total_amount': 120,
#   'status': 'Completed'},
#  {'order_id': 2,
#   'customer_name': 'Raheel',
#   'total_amount': 80,
#   'status': 'Pending'},
#  {'order_id': 3,
#   'customer_name': 'Saleem',
#   'total_amount': 150,
#   'status': 'Completed'},
#  {'order_id': 4,
#   'customer_name': 'khushnoor',
#   'total_amount': 95,
#   'status': 'Completed'},
#  {'order_id': 5,
#   'customer_name': 'Alizy',
#   'total_amount': 200,
#   'status': 'Pending'},
#  {'order_id': 6,
#   'customer_name': 'javaid',
#   'total_amount': 85,
#   'status': 'Completed'},
#  {'order_id': 7,
#   'customer_name': 'Talha',
#   'total_amount': 150,
#   'status': 'Pending'},
#  {'order_id': 8,
#   'customer_name': 'Naveed',
#   'total_amount': 200,
#   'status': 'Completed'}]

# %% [markdown]
# #### Write a Python program to create a list of "customer_name" for all orders
# #### where the total_amount is less than 100 and the order status is "Completed".

# %%
order_ids2 = [order['customer_name'] for order in Ec_Store_Orders if order['total_amount'] < 100 and order['status'] == 'Completed']

# %%
order_ids2
# Out:
# ['khushnoor', 'javaid']

# %% [markdown]
# ## **Functions**
# A function is a reusable block of code that performs a specific task.
#
# - Reusability: Once a function is defined, you can call it multiple times without having to rewrite the same code.

# %%
def greet():
    print('welcome')

# %%
greet
# Out:
# <function __main__.greet()>

# %%
greet()
# Out:
# welcome

# %%
def greet1(name):
    print('welcome', name)

# %%
greet1('Ali')
# Out:
# welcome Ali

# %%
greet1('Sumbal')
# Out:
# welcome Sumbal

# %%
greet1('Ali', 'Ahmed')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 greet1('Ali', 'Ahmed')
#
# TypeError: greet1() takes 1 positional argument but 2 were given

# %%
def add(a,b):
    print(a+b)

# %%
add(1,2)
# Out:
# 3

# %%
add(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 add(1,2,3)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def sub(x, y=2):
    print(x-y)

# %%
sub(1)
# Out:
# -1

# %%
sub(2,4)
# Out:
# -2

# %%
sub(x=2, y= 5)
# Out:
# -3

# %%
sub(x=3, 5)
# Out:
#   Cell In[29], line 1
#     sub(x=3, 5)
#               ^
# SyntaxError: positional argument follows keyword argument

# %%
sub(3, y=5)
# Out:
# -2

# %%
def mul(a,b):
    print(a*b)

# %%
mul(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 mul(4)
#
# TypeError: mul() missing 1 required positional argument: 'b'

# %%
def add(a=3, b=5):
    print(a+b)

# %%
add()
add(4)
add(5,6)
# Out:
# 8
# 9
# 11

# %%
def fruit(*args):
    print(args)

# %%
fruit('apple', 'banana', 'orange')
# Out:
# ('apple', 'banana', 'orange')

# %%
def fruit(*args):
    print(list(args))

# %%
fruit('apple', 'banana', 'orange')
# Out:
# ['apple', 'banana', 'orange']

# %%
fruit(a='apple', b='banana')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 fruit(a='apple', b='banana')
#
# TypeError: fruit() got an unexpected keyword argument 'a'

# %%
fruit('apple', 'banana', 'orange', 'melon')
# Out:
# ['apple', 'banana', 'orange', 'melon']

# %%
def greet(name):
    print('Hello', name)

greet('ali')
greet('aymen')

# %%
def add(a,b):
    print(a+b) #parameters a,b

add(1)

# %%
def add(a,b):
    print(a+b) #parameters a,b

add(1,5)

# %%
def calculate_salary(basic_salary, bonus):
    total_salary = basic_salary + bonus
    return total_salary
calculate_salary(1500,300)

# %%
#Default parameter
def greet(name="Guest"):
    print(f"Hello, {name}!")
greet()
greet('sumbal')

# %%
def add(a=2,b=4):
    print(a+b)

add()
add(9)
add(8,3)

# %% [markdown]
# #### **Arbitrary arguments**

# %%
def fruits(*abc):
    return abc

fruits('apple','orange','cherry')

# %%
def fruits(*abc):
    return abc

fruits(a='apple',b='orange',c='cherry')

# %%
def fruits(*abc):
    return list(abc)

fruits('apple','orange','cherry')

# %% [markdown]
# #### Write a function that accepts marks of any number of students and prints the total marks.

# %%
def total_marks(*abc):
    print(f'total sum: {sum(abc)}')

# %%
total_marks(22,33,10)
# Out:
# total sum: 65

# %% [markdown]
# #### Write a function that accepts prices of any number of products and prints the highest price.

# %%
def highest(*xyz):
    print(f'highest value: {max(xyz)}')
highest(100,200,95,359,40)
# Out:
# highest value: 359

# %% [markdown]
# #### Write a function that accepts any number of temperatures and prints the average temperature.

# %%
def avg(*abc):
    average = sum(abc)/len(abc)
    print(average)

# %%
avg(3,5,7)
# Out:
# 5.0

# %% [markdown]
# #### Write a function that accepts any number of shopping items and prints each item.

# %%
def shopping_list(*items):
    for item in items:
        print(item)

# %%
shopping_list('buuter', 'bread', 'milk', 'egg')
# Out:
# buuter
# bread
# milk
# egg

# %%
def total_marks(*marks):
    print("Total Marks:", sum(marks))

total_marks(80, 75, 90, 85)

# %%
def average_temp(*temps):
    avg = sum(temps) / len(temps)
    print("Average Temperature:", avg)

average_temp(30, 32, 28, 35, 31)

# %%
def highest_price(*prices):
    print("Highest Price:", max(prices))

highest_price(250, 400, 150, 600, 350)

# %%
def shopping_list(*items):
    for item in items:
        print(item)

shopping_list("Milk", "Bread", "Eggs", "Butter")

# %% [markdown]
# #### **Arbitrary Keyword Arguments**

# %%
def xyz(**kargs):
    print(kargs)

xyz(name='Ali', age=22)
# Out:
# {'name': 'Ali', 'age': 22}

# %%
xyz()
# Out:
# {}

# %%
xyz(123, name='umair', age=23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 xyz(123, name='umair', age=23)
#
# TypeError: xyz() takes 0 positional arguments but 1 was given

# %%
def greet(**xyz):
    return xyz

greet(name='umair', age=22)

# %%
def greet(**xyz):
    return xyz

greet('ali', name='umair', age=22)

# %% [markdown]
# #### Write a function that accepts employee details using keyword arguments and prints each detail.

# %%
def emp_details(**kargs):
    for key, value in kargs.items():
        print(f'key: {key} value: {value}')

# %%
emp_details(name='ali', age=23, job='teacher')
# Out:
# key: name value: ali
# key: age value: 23
# key: job value: teacher

# %%
emp_details(emp_id=111, age=23, job='teacher')
# Out:
# key: emp_id value: 111
# key: age value: 23
# key: job value: teacher

# %% [markdown]
# #### Write a function that accepts product information using keyword arguments and prints all the details.

# %%
def total_bill(**items):
    print("Total Bill:", sum(items.values()))

total_bill(Burger=500, Pizza=1200, Drink=200)
# Out:
# Total Bill: 1900

# %% [markdown]
# #### Write a function that accepts item prices using keyword arguments and prints the total bill.

# %%
#Combination of *args and **kwargs
def bio(*args, **kwargs):
    print('positional arguments', args)
    print('keyword arguments', kwargs)

bio('ahmed',22,'karachi',gender='Male',Salary=200000)
# Out:
# positional arguments ('ahmed', 22, 'karachi')
# keyword arguments {'gender': 'Male', 'Salary': 200000}

# %%
#Combination of *args and **kwargs
def bio(*args, **kwargs):
    print('positional arguments', args)
    print('keyword arguments', kwargs)

bio(gender='Male',Salary=200000,'ahmed',22,'karachi')
# Out:
#   Cell In[57], line 6
#     bio(gender='Male',Salary=200000,'ahmed',22,'karachi')
#                                                         ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# A company wants to calculate an employee's net salary. Write a Python function calculate_salary() that takes:
#
# basic_salary as a required argument,
# any number of allowances (e.g., house allowance, transport allowance, medical allowance) using *args,
# any number of deductions (e.g., tax, insurance, loan) using **kwargs.
#
# The function should:
#
# Calculate the total allowances.
# Calculate the total deductions.
# Calculate the gross salary.
# Calculate the net salary.
# Display the basic salary, total allowances, total deductions, and net salary.

# %%
def calculate_salary(basic,*allowances, **deductions):
    total_allowance = sum(allowances)
    total_deductions = sum(deductions.values())
    gross_salary = basic + total_allowance
    net_salary = gross_salary - total_deductions

    print('basic salary', basic)
    print('total allowance: ', total_allowance)
    print('total deduction: ', total_deductions)
    print('gross salary:', gross_salary)
    print('net salary: ', net_salary)

# %%
calculate_salary(5000, 2000,1000, tax=3000,insurance=200)
# Out:
# basic salary 5000
# total allowance:  3000
# total deduction:  3200
# gross salary: 8000
# net salary:  4800

# %% [markdown]
# ### Nested Function

# %%
def outer():
    def inner():
        print('welcome')
    inner()
    
outer()
# Out:
# welcome

# %%
def outer1():
    def inner1():
        print('welcome')
outer1()

# %%
inner1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 inner1()
#
# NameError: name 'inner1' is not defined

# %%
outer()
# Out:
# welcome

# %%
def outer():
    def inner():
        print("Hello")
    inner()

outer()

# %% [markdown]
# #### Write a Python program using a nested function. The outer function should accept student marks, and the inner function should calculate the grade.

# %%
def student(marks):
    def grade(marks):
        if marks >= 80:
            print('A1')
        elif marks >= 60:
            print('A')
        else:
            print('B')
    grade(marks)

# %%
student(75)
# Out:
# A

# %% [markdown]
# #### Write a Python program using a nested function. The outer function should accept the basic salary, and the inner function should calculate a 15% bonus. Print basic salary, bonus, and total(basic + bonus)

# %%
def outer(basic):
    def inner(basic):
        bonus = basic * 0.15
        print(bonus)
    inner(basic)
outer(10)
# Out:
# 1.5
