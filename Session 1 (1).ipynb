# %%
hello world
# Out:
#   Cell In[1], line 1
#     hello world
#           ^
# SyntaxError: invalid syntax

# %%
print("hello world")
# Out:
# hello world

# %%
type("hello world")
# Out:
# str

# %%
print(123)
# Out:
# 123

# %%
123
# Out:
# 123

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
print(type("hello world"))
# Out:
# <class 'str'>

# %%
type(1234)
# Out:
# int

# %%
1234
# Out:
# 1234

# %%
print(1234)
# Out:
# 1234

# %%
print(123.67)
# Out:
# 123.67

# %%
type(123.67)
# Out:
# float

# %%
type("123.678")
# Out:
# str
