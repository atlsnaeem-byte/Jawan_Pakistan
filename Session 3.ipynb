# %% [markdown]
# # List

# %%
[20k,30,60k,90k,50k,75k,40k,30k]
# Out:
#   Cell In[1], line 1
#     [20k,30,60k,90k,50k,75k,40k,30k]
#       ^
# SyntaxError: invalid decimal literal

# %%
20k
# Out:
#   Cell In[2], line 1
#     20k
#      ^
# SyntaxError: invalid decimal literal

# %%
"20k"
# Out:
# '20k'

# %%
["20k","30k","60k","90k","50k","75k","40k","30k"]
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries = ["20k","30k","60k","90k","50k","75k","40k","30k"]

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
len(salaries)
# Out:
# 8

# %% [markdown]
# ## Indexing

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries[3]
# Out:
# '90k'

# %%
salaries[7]
# Out:
# '30k'

# %%
salaries[-2]
# Out:
# '40k'

# %%
bio = ['sana',25,salaries,456.9,'sana@gmail']

# %%
bio
# Out:
# ['sana',
#  25,
#  ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k'],
#  456.9,
#  'sana@gmail']

# %%
bio
# Out:
# ['sana',
#  25,
#  ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k'],
#  456.9,
#  'sana@gmail']

# %%
bio[2]
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
bio[2][3]
# Out:
# '90k'

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %% [markdown]
# ## Slicing

# %%
salaries[1,2,3,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 salaries[1,2,3,4]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
salaries[1:5]
# Out:
# ['30k', '60k', '90k', '50k']

# %%
salaries[1:4]
# Out:
# ['30k', '60k', '90k']

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries[-3:-6]
# Out:
# []

# %%
salaries[-5:-2]
# Out:
# ['90k', '50k', '75k']

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries[1:6]
# Out:
# ['30k', '60k', '90k', '50k', '75k']

# %%
salaries[1:6:2]
# Out:
# ['30k', '90k', '75k']

# %%
salaries[1:6:3]
# Out:
# ['30k', '50k']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
type(salaries)
# Out:
# list

# %%
bio.index('sana@gmail')
# Out:
# 4

# %%
salaries[2:]
# Out:
# ['60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries[:5]
# Out:
# ['20k', '30k', '60k', '90k', '50k']

# %%
bio
# Out:
# ['sana',
#  25,
#  ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k'],
#  456.9,
#  'sana@gmail']

# %%
print(bio)
# Out:
# ['sana', 25, ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k'], 456.9, 'sana@gmail']
