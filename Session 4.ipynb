# %%
salaries = ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
type(salaries)
# Out:
# list

# %%
dir(salaries)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries.Append('75k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 salaries.Append('75k')
#
# AttributeError: 'list' object has no attribute 'Append'

# %%
salaries.append('75k')

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k', '75k']

# %%
salaries.insert(3,"100k")

# %%
salaries
# Out:
# ['20k', '30k', '60k', '100k', '90k', '50k', '75k', '40k', '30k', '75k']

# %%
salaries[4]
# Out:
# '90k'

# %%
salaries[4] = "95k"

# %%
salaries
# Out:
# ['20k', '30k', '60k', '100k', '95k', '50k', '75k', '40k', '30k', '75k']

# %%
salaries[4:7]
# Out:
# ['95k', '50k', '75k']

# %%
salaries[4:7] = "70k","45k","67k"

# %%
salaries
# Out:
# ['20k', '30k', '60k', '100k', '70k', '45k', '67k', '40k', '30k', '75k']

# %%
salaries[:2] = ["70k","45k"]

# %%
salaries
# Out:
# ['70k', '45k', '60k', '100k', '70k', '45k', '67k', '40k', '30k', '75k']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['70k', '45k', '60k', '100k', '70k', '45k', '67k', '40k', '30k', '75k']

# %%
salaries.clear('45k')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 salaries.clear('45k')
#
# TypeError: list.clear() takes no arguments (1 given)

# %%
salaries.clear()

# %%
salaries
# Out:
# []

# %%
salaries = ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
Copy = salaries.copy()

# %%
Copy
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries.count('30k')
# Out:
# 2

# %%
salaries
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
Copy
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
salaries.extend(Copy)

# %%
salaries
# Out:
# ['20k',
#  '30k',
#  '60k',
#  '90k',
#  '50k',
#  '75k',
#  '40k',
#  '30k',
#  '20k',
#  '30k',
#  '60k',
#  '90k',
#  '50k',
#  '75k',
#  '40k',
#  '30k']

# %%
len(salaries)
# Out:
# 16

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
Copy
# Out:
# ['20k', '30k', '60k', '90k', '50k', '75k', '40k', '30k']

# %%
Copy.remove('60k')

# %%
Copy
# Out:
# ['20k', '30k', '90k', '50k', '75k', '40k', '30k']

# %%
Copy.pop()
# Out:
# '30k'

# %%
Copy
# Out:
# ['20k', '30k', '90k', '50k', '75k', '40k']

# %%
Copy.pop(-2)
# Out:
# '75k'

# %%
Copy
# Out:
# ['20k', '30k', '90k', '50k', '40k']

# %%
Copy.reverse()

# %%
Copy
# Out:
# ['40k', '50k', '90k', '30k', '20k']

# %%
num = [1,10,4,7,1,8,9,50,11]

# %%
num
# Out:
# [1, 10, 4, 7, 1, 8, 9, 50, 11]

# %%
num.sort()

# %%
num
# Out:
# [1, 1, 4, 7, 8, 9, 10, 11, 50]

# %% [markdown]
# # list
# # Create a list: [10, 20, 30]
# Insert 15 at index 1.
#
#
# # Create a list of colors.
# Remove one color using remove().
#
# #Remove "apple" from this list:
# ["banana", "apple", "mango"]
#
# # Sort this list in ascending order:
# [5, 2, 9, 1, 7]
#
#
# # Find the index of "mango" in:
# ["apple", "mango", "banana"]

# %% [markdown]
# # String's method

# %%
prog_lang = "we are learning python"

# %%
type(prog_lang)
# Out:
# str

# %%
dir(prog_lang)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(" ")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
prog_lang
# Out:
# 'we are learning python'

# %%
prog_lang.capitalize()
# Out:
# 'We are learning python'

# %%
upper = prog_lang.upper()
upper
# Out:
# 'WE ARE LEARNING PYTHON'

# %%
upper.lower()
# Out:
# 'we are learning python'

# %%
prog_lang
# Out:
# 'we are learning python'

# %%
prog_lang.title()
# Out:
# 'We Are Learning Python'

# %%
'1234'.isnumeric()
# Out:
# True

# %%
'134wwr'.isalpha()
# Out:
# False

# %%
'134wwr'.isalnum()
# Out:
# True

# %%
dir(" ")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
message = 'Python is a fun programming language'

# check the index of 'fun'
print(message.find('fun'))

# Output: 12
# Out:
# 12

# %%
text = 'Python is fun'

# find the index of is
result = text.index('is')
print(result)

# Output: 7
# Out:
# 7

# %%
text = 'Python is fun'

text.index('is')
# Out:
# 7

# %%
'Python is fun'.index('is')
# Out:
# 7

# %%
dir(" ")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
# default arguments
print("Hello {}, your balance is {}.".format("Adam", 230.2346))
# Out:
# Hello Adam, your balance is 230.2346.

# %%
name = "Adam"
bal = 230.345
print(f'Hello {name}, your balance is {bal}')
# Out:
# Hello Adam, your balance is 230.345

# %%
# positional arguments
print("Hello {0}, your balance is {1}.".format("Adam", 230.2346))

# keyword arguments
print("Hello {name}, your balance is {blc}.".format(name="Adam", blc=230.2346))

# mixed arguments
print("Hello {0}, your balance is {blc}.".format("Adam", blc=230.2346))
# Out:
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.

# %%
strip = '   Python is fun    '

# %%
strip
# Out:
# '   Python is fun    '

# %%
strip.strip()
# Out:
# 'Python is fun'

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
strip
# Out:
# '   Python is fun    '

# %%
strip.lstrip()
# Out:
# 'Python is fun    '

# %%
text
# Out:
# 'Python is fun'

# %%
message
# Out:
# 'Python is a fun programming language'

# %%
message.split()
# Out:
# ['Python', 'is', 'a', 'fun', 'programming', 'language']

# %%
"khushboosaleem@gmail.com".split()
# Out:
# ['khushboosaleem@gmail.com']

# %%
"khushboosaleem@gmail.com".split('@')
# Out:
# ['khushboosaleem', 'gmail.com']

# %%
"khushboosaleem@gmail.com".split('.')
# Out:
# ['khushboosaleem@gmail', 'com']

# %%
"khushboosaleem_gmail.com".split('_')
# Out:
# ['khushboosaleem', 'gmail.com']

# %%
message
# Out:
# 'Python is a fun programming language'

# %%
java = message.replace("Python","Java")

# %%
java
# Out:
# 'Java is a fun programming language'

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
# Remove the extra spaces from both ends of the string " Hello World ".
# Remove spaces only from the left side of " Start now".
# Remove trailing spaces from "Finish line ".
# Replace "apple" with "banana" in the sentence "I have an apple".
# Remove the .jpg suffix from "picture.jpg".
# Remove the "Mr. " prefix from "Mr. John".
# How many times does the letter "e" appear in "experience"?
# Find the position of "@" in the email "user@example.com".
