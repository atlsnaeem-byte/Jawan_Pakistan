# %% [markdown]
# ## Tuple
#
# In Python, a tuple is used to store multiple values in a single variable, just like a list. However, tuples are immutable, which means their values cannot be changed after creation.

# %%
bio = ("sara",45,"biryani","sara@gmail.com")
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com')

# %%
bio[3]
# Out:
# 'sara@gmail.com'

# %%
bio[-1]
# Out:
# 'sara@gmail.com'

# %%
bio[1]
# Out:
# 45

# %%
bio[1] = 25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bio[1] = 25
#
# TypeError: 'tuple' object does not support item assignment

# %%
dir(())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
bio = ("sara",45,"biryani","sara@gmail.com",45)
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
bio.count(45)
# Out:
# 2

# %%
bio.index("biryani")
# Out:
# 2

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
bio_list = list(bio)

# %%
bio_list
# Out:
# ['sara', 45, 'biryani', 'sara@gmail.com', 45]

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
bio.append(67)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 bio.append(67)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple(bio_list)
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
type(bio)
# Out:
# tuple

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
bio[1:]
# Out:
# (45, 'biryani', 'sara@gmail.com', 45)

# %%
bio[1:4]
# Out:
# (45, 'biryani', 'sara@gmail.com')

# %%
len(bio)
# Out:
# 5

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %% [markdown]
# # Unpacking

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
len(bio)
# Out:
# 5

# %%
name,age,food,email = bio
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 name,age,food,email = bio
#
# ValueError: too many values to unpack (expected 4)

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
name,age,food,email,num = bio

# %%
name
# Out:
# 'sara'

# %%
age
# Out:
# 45

# %%
num
# Out:
# 45

# %%
email
# Out:
# 'sara@gmail.com'

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
name,age,*info = bio

# %%
name
# Out:
# 'sara'

# %%
age
# Out:
# 45

# %%
info
# Out:
# ['biryani', 'sara@gmail.com', 45]

# %%
bio_list
# Out:
# ['sara', 45, 'biryani', 'sara@gmail.com', 45]

# %%
name_list,age_list,*info_list = bio_list

# %%
name_list
# Out:
# 'sara'

# %%
info_list
# Out:
# ['biryani', 'sara@gmail.com', 45]

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
*name,age,x = bio

# %%
name
# Out:
# ['sara', 45, 'biryani']

# %%
age
# Out:
# 'sara@gmail.com'

# %%
x
# Out:
# 45

# %%
bio
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
name,*info,y = bio

# %%
info
# Out:
# [45, 'biryani', 'sara@gmail.com']

# %%
tup_in_tup = (bio,39,"karachi")

# %%
tup_in_tup
# Out:
# (('sara', 45, 'biryani', 'sara@gmail.com', 45), 39, 'karachi')

# %%
len(tup_in_tup)
# Out:
# 3

# %%
tup_in_tup[0]
# Out:
# ('sara', 45, 'biryani', 'sara@gmail.com', 45)

# %%
tup_in_tup[0][0]
# Out:
# 'sara'

# %%
tup_in_tup[0][0] = "sana"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 tup_in_tup[0][0] = "sana"
#
# TypeError: 'tuple' object does not support item assignment

# %%
bio_list
# Out:
# ['sara', 45, 'biryani', 'sara@gmail.com', 45]

# %%
tup_in_list = (bio_list,"karachi",67)

# %%
tup_in_list
# Out:
# (['sara', 45, 'biryani', 'sara@gmail.com', 45], 'karachi', 67)

# %%
tup_in_list[0]
# Out:
# ['sara', 45, 'biryani', 'sara@gmail.com', 45]

# %%
tup_in_list[0][0]
# Out:
# 'sara'

# %%
tup_in_list[0][0] = "sana"

# %%
tup_in_list
# Out:
# (['sana', 45, 'biryani', 'sara@gmail.com', 45], 'karachi', 67)

# %%
list_in_tup = [bio,45]

# %%
list_in_tup
# Out:
# [('sara', 45, 'biryani', 'sara@gmail.com', 45), 45]

# %%
list_in_tup[0][0] = 'khus'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 list_in_tup[0][0] = 'khus'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Dictionary
#
# In Python, a dictionary is mutable collection of key value pairs. It is one of the most versatile data structures in Python, allowing you to efficiently store and retrieve data based on custom keys.

# %%
my_dict = {
    "name":"sana",
    "age":35,
    "city":"karachi"
}

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 35, 'city': 'karachi'}

# %%
my_dict["name"]
# Out:
# 'sana'

# %%
my_dict.get("age")
# Out:
# 35

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
my_dict.values()
# Out:
# dict_values(['sana', 35, 'karachi'])

# %%
my_dict.items()
# Out:
# dict_items([('name', 'sana'), ('age', 35), ('city', 'karachi')])

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 35, 'city': 'karachi'}

# %%
my_dict.update({"email":"sana@gmail.com"})

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 35, 'city': 'karachi', 'email': 'sana@gmail.com'}

# %%
my_dict.update({'age':25})

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 25, 'city': 'karachi', 'email': 'sana@gmail.com'}

# %%
my_dict['city']
# Out:
# 'karachi'

# %%
my_dict['city'] = 'multan'

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 25, 'city': 'multan', 'email': 'sana@gmail.com'}

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 25, 'city': 'multan', 'email': 'sana@gmail.com'}

# %%
my_dict['food'] = "Pizza"

# %%
my_dict
# Out:
# {'name': 'sana',
#  'age': 25,
#  'city': 'multan',
#  'email': 'sana@gmail.com',
#  'food': 'Pizza'}

# %%
my_dict.popitem()
# Out:
# ('food', 'Pizza')

# %%
my_dict
# Out:
# {'name': 'sana', 'age': 25, 'city': 'multan', 'email': 'sana@gmail.com'}

# %%
# Nested Dictionaries
employee = {
    101 : {'name': 'khan', 'age' : 22, 'Salary' : 2222222},
    102 : {'name': 'alice', 'age' : 33, 'Salary' : 2222},
    103 : {'name': 'john cena', 'age' : 11, 'Salary' : 22}
}

# %%
employee.get(101).get("age")
# Out:
# 22

# %%
employee.get(101,"age")
# Out:
# {'name': 'khan', 'age': 22, 'Salary': 2222222}

# %%
employee[101]
# Out:
# {'name': 'khan', 'age': 22, 'Salary': 2222222}

# %%
employee[101]['age']
# Out:
# 22

# %%
employee[101]['age'] = 25

# %%
employee
# Out:
# {101: {'name': 'khan', 'age': 25, 'Salary': 2222222},
#  102: {'name': 'alice', 'age': 33, 'Salary': 2222},
#  103: {'name': 'john cena', 'age': 11, 'Salary': 22}}

# %%
employee[101:102]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 employee[101:102]
#
# KeyError: slice(101, 102, None)

# %%
employee.get(101)
# Out:
# {'name': 'khan', 'age': 25, 'Salary': 2222222}

# %%
my_info = dict(name = "khus", age = 26, email = "khushboo@gmail.com")

# %%
my_info
# Out:
# {'name': 'khus', 'age': 26, 'email': 'khushboo@gmail.com'}

# %% [markdown]
# ## SET {}
# A set in Python is an unordered collection of unique elements. This means that a set cannot contain duplicate values, and the elements are stored in no specific order.
#
# Unordered: The elements in a set do not maintain any specific order.
#
# Unique: Sets cannot contain duplicate elements. If you try to add a duplicate element, it will not be added.
#
# Mutable: You can add or remove elements from a set after it is created.
#
# No indexing: Sets do not support indexing or slicing like lists.

# %%
num = {1,2,3,3,4,5,5,10,10}

# %%
num
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
dir(set())
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
dir(num)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
set1 = {1, 2, 3}
set2 = {2, 3}

set1.difference_update(set2)
print(set1)
# Out:
# {1}

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}

print(set1.difference(set2))
# Out:
# {1}

# %%
print(set2.difference(set1))
# Out:
# {4}

# %%
python_students = {"Ali", "Ahmed", "Sara"}
sql_students = {"Sara", "Ahmed", "Ayesha"}

common_students = python_students.intersection(sql_students)
common_students
# Out:
# {'Ahmed', 'Sara'}

# %% [markdown]
# ## 1
# Create a set of numbers and remove duplicates from:
#
# [1, 2, 2, 3, 4, 4, 5]

# %%
set([1, 2, 2, 3, 4, 4, 5])
# Out:
# {1, 2, 3, 4, 5}

# %%
# tuple()
# list()
# set()
# dict()

# %% [markdown]
# # Tuple Practice Questions
#
# ## 1
# Create a tuple of 5 fruits and print the third fruit.
#
# ## 2
# Write a program to count how many times `2` appears in this tuple:
# (1, 2, 3, 2, 4, 2, 5)
#
#
# ## 3
# Create a tuple of 3 student names and unpack them into variables.
#
# ## 4
# Find the index of `"Python"` in this tuple:
# ("Java", "C++", "Python", "SQL")
#
# ## 5
# Write a program to slice the tuple and print only the middle 3 elements:
# (10, 20, 30, 40, 50, 60, 70)

# %% [markdown]
# # Dictionary Practice Questions
#
# ## 1
# Create a dictionary of a student with keys: name, age, marks, city.
#
# ## 2
# Print only the keys of this dictionary:
#
# {"A": 10, "B": 20, "C": 30}
#
#
# ## 3
# Update the age of a student from 20 to 21 in a dictionary.
#
# ## 5
# Create a dictionary of 3 products with price and print the price of one product.

# %% [markdown]
# # Set Practice Questions
#
# ## 1
# Create a set of numbers and remove duplicates from:
#
# [1, 2, 2, 3, 4, 4, 5]
#
#
# ## 2
# Find common elements between:
#
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
#
#
# ## 3
# Add `"orange"` and `"mango"` to an existing set of fruits.
#
# ## 4
# Remove `"banana"` using both remove() and discard().
#
# ## 5
# Find the union of:
#
# X = {10, 20, 30}
# Y = {30, 40, 50}
