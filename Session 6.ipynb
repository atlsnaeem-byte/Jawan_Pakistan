# %% [markdown]
# ## Comparison Operators
# #### Comparison operators are used to compare two values. These operators return a Boolean value (True or False), and are commonly used in if, elif, and while statements.
# ### (== , != , < , > , >= , <=)

# %%
x = 7
y = 9

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x > y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
x >= y
# Out:
# False

# %%
y >= x
# Out:
# True

# %%
9 >= 7
# Out:
# True

# %% [markdown]
# ## Assignment Operators (*=, +=, -=)

# %% [markdown]
# #### Operators that are used to assign a value to a variable, and in some cases, update the variable’s existing value.

# %%
x = 3
x
# Out:
# 3

# %%
x + 3
# Out:
# 6

# %%
x
# Out:
# 3

# %%
x = x + 3
x
# Out:
# 6

# %%
x
# Out:
# 6

# %%
x += 5

# %%
x
# Out:
# 11

# %%
y = 10
y
# Out:
# 10

# %%
y -=5
y
# Out:
# 5

# %%
y
# Out:
# 5

# %%
z = 6
z
# Out:
# 6

# %%
z *= 2

# %%
z
# Out:
# 12

# %% [markdown]
# # Logical Operators
# #### Logical operators allow you to combine multiple conditions into one complex condition. These operators are commonly used to combine relational conditions and make decisions based on multiple criteria.
# #### and, or, not

# %%
9 > 7 and 6 < 5
# Out:
# False

# %%
9 > 7
# Out:
# True

# %%
6 < 5
# Out:
# False

# %%
8 >= 7
# Out:
# True

# %%
8 >= 7 and 9 ==9 and 9 > 6
# Out:
# True

# %%
8 >= 7 and 9 ==9 and 9 < 6
# Out:
# False

# %%
6 > 4 or 5 > 8
# Out:
# True

# %%
6 > 4 and 5 > 8
# Out:
# False

# %%
not (6 > 4 or 5 > 8)
# Out:
# False

# %%
8 >= 7 or 9 ==9 or 9 < 6
# Out:
# True

# %%
not (11 > 3) or (11 > 9 and 9 == 9)
# Out:
# True

# %%
11 > 3
# Out:
# True

# %%
11 > 9
# Out:
# True

# %%
9 == 9
# Out:
# True

# %%
(11 > 9 and 9 == 9)
# Out:
# True

# %%
not ((11 > 3) or (11 > 9 and 9 == 9))
# Out:
# False

# %% [markdown]
# ### Membership Operators (IN - NOT IN)

# %% [markdown]
# #### Membership operators are used to test whether a value is present in a sequence (such as a list, tuple, or string). (returns Ture or False)

# %%
text = 'Python'
text
# Out:
# 'Python'

# %%
'P' in text
# Out:
# True

# %%
'p' in text
# Out:
# False

# %%
'p' in not text
# Out:
#   Cell In[43], line 1
#     'p' in not text
#            ^
# SyntaxError: invalid syntax

# %%
'p' not in text
# Out:
# True

# %%
colors = ['red', 'black', 'white', 'r']
colors
# Out:
# ['red', 'black', 'white', 'r']

# %%
'r' in colors
# Out:
# True

# %%
'red' in colors
# Out:
# True

# %% [markdown]
# #### Check if a person is old enough to vote (age >= 18). Just print the Boolean result.
#
# #
#
# #### Compare the lengths of two strings and print if they are equal
#
# #
#
# #### Is a number divisible by 3 or 5?
#
# #
#
# #### Check if the word 'code' is in the sentence
# #### sentence = "I love to write code every day"

# %%
# Is a number divisible by 3 or 5?
num = 15

num % 3 == 0 or num % 5 == 0
# Out:
# True

# %%
num % 5
# Out:
# 3

# %% [markdown]
# ## Input Function

# %%
input()
# Out:
#  heeuur
# 'heeuur'

# %%
input('enter your name')
# Out:
# enter your name sumbal
# 'sumbal'

# %%
input('enter your name')
# Out:
# enter your name Sumbal
# 'Sumbal'

# %%
num1 = input('enter first number : ')
num2 = input('enter second number :')
add = num1 + num2
print(add)
# Out:
# enter first number :  2
# enter second number : 3
# 23

# %%
num1 = input('enter first number : ')
num2 = input('enter second number :')
add = num1 - num2
print(add)
# Out:
# enter first number :  2
# enter second number : 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 num1 = input('enter first number : ')
#       2 num2 = input('enter second number :')
# ----> 3 add = num1 - num2
#       4 print(add)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
num1 = int(input('enter first number: '))
num2 = int(input('enter second number: '))
add = num1 + num2
print(add)
# Out:
# enter first number:  2
# enter second number:  3
# 5

# %% [markdown]
# ## if-elif-else

# %%
light = 'red'
if light == 'red'
print('stop')
# Out:
#   Cell In[62], line 2
#     if light == 'red'
#                      ^
# SyntaxError: expected ':'

# %%
light = 'red'
if light == 'red':
print('stop')
# Out:
#   Cell In[63], line 3
#     print('stop')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
light = 'red'
if light == 'red':
    print('stop')
# Out:
# stop

# %%
light = 'green'
if light == 'red':
    print('stop')

# %%
light = 'green'
if light == 'red':
    print('stop')
else:
    print('go')
# Out:
# go

# %%
light = 'yellow'
if light == 'red':
    print('stop')
elif light == 'green':
    print('go')
elif light == 'yellow':
    print('ready')
else:
    print('system error')
# Out:
# ready

# %%
light = 'red'
if light == 'red':
    print('stop')
elif light == 'green':
    print('go')
elif light == 'yellow':
    print('ready')
else:
    print('system error')
# Out:
# stop

# %%
light = 'black'
if light == 'red':
    print('stop')
elif light == 'green':
    print('go')
elif light == 'yellow':
    print('ready')
else:
    print('system error')
# Out:
# system error

# %%
light = input('select a color from red/yellow/green').lower()


if light == 'red':
    print('stop')
elif light == 'green':
    print('go')
elif light == 'yellow':
    print('ready')
else:
    print('system error')
# Out:
# select a color from red/yellow/green RED
# stop

# %%
marks = 101

if marks >= 80 and marks <= 100:
    print('A+')
elif marks >= 70 and marks < 80:
    print('A')
elif marks >= 60 and marks < 70:
    print('B')
elif marks >= 50 and marks < 60:
    print('C')
elif marks >= 0 and marks < 50:
    print('F')
else:
    print('invalid')
# Out:
# invalid

# %%
marks = 98

if marks >= 80 and marks <= 100:
    print('A+')
elif marks >= 70 and marks < 80:
    print('A')
elif marks >= 60 and marks < 70:
    print('B')
elif marks >= 50 and marks < 60:
    print('C')
elif marks >= 0 and marks < 50:
    print('F')
else:
    print('invalid')
# Out:
# A+

# %%
marks = 34

if marks >= 80 and marks <= 100:
    print('A+')
elif marks >= 70 and marks < 80:
    print('A')
elif marks >= 60 and marks < 70:
    print('B')
elif marks >= 50 and marks < 60:
    print('C')
elif marks >= 0 and marks < 50:
    print('F')
else:
    print('invalid')
# Out:
# F

# %%
marks = -34

if marks >= 80 and marks <= 100:
    print('A+')
elif marks >= 70 and marks < 80:
    print('A')
elif marks >= 60 and marks < 70:
    print('B')
elif marks >= 50 and marks < 60:
    print('C')
elif marks >= 0 and marks < 50:
    print('F')
else:
    print('invalid')
# Out:
# invalid

# %%
marks = 101

if marks >= 80 and marks <= 100:
    print('A+')
elif marks >= 70 and marks < 80:
    print('A')
elif marks >= 60 and marks < 70:
    print('B')
elif marks >= 50 and marks < 60:
    print('C')
elif marks >= 0 and marks < 50:
    print('fail')
else:
    print('invalid marks')
# Out:
# invalid marks

# %% [markdown]
# ## Nested if

# %%
visa = "valid"
purpose = "education"

# %%
if visa == 'valid':
    if purpose == 'education':
        print('welcome')
# Out:
# welcome

# %%
if visa == 'valid':
    if purpose == 'job':
        print('welcome')

# %%
if visa == 'valid':
    if purpose == 'job':
        print('welcome')
    else:
        print('your purpose is not education')
# Out:
# your purpose is not education

# %%
if visa == 'valid':
    if purpose == 'education':
        print('welcome')
    else:
        print('your purpose is not education')
# Out:
# welcome

# %%
if visa == 'invalid':
    if purpose == 'education':
        print('welcome')
    else:
        print('your purpose is not education')

# %%
if visa == 'invalid':
    if purpose == 'education':
        print('welcome')
    else:
        print('your purpose is not education')
else:
    print('invalid visa')
# Out:
# invalid visa

# %%
if visa == 'valid':
    if purpose == 'job':
        print('welcome')
    else:
        print('your purpose is not education')
else:
    print('invalid visa')
# Out:
# your purpose is not education

# %% [markdown]
# ### Write a program that asks the user to enter a number.
#
# If the number is even and greater than 50, print "Even and Big".
#
# If the number is even and less than or equal to 50, print "Even and Small".
#
# If the number is odd and greater than 50, print "Odd and Big".
#
# Otherwise, print "Odd and Small".

# %%
num = int(input('enter a number'))

if num % 2 == 0 and num > 50:
    print('even and big')
elif num % 2 == 0 and num <=50:
    print('even and small')
elif num % 2 != 0 and num > 50:
    print('odd and big')
else:
    print('odd and small')
# Out:
# enter a number 25
# odd and small
