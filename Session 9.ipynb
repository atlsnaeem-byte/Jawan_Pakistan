# %% [markdown]
# # Error Handling

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
print(1/'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(1/'a')
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
print(3*5)
print(1/0)
print(2+4)
# Out:
# 15
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print(3*5)
# ----> 2 print(1/0)
#       3 print(2+4)
#
# ZeroDivisionError: division by zero

# %%
print(3*5)

try:
    print(1/0)
except ZeroDivisionError:
    print("Cannot divided by zero")

print(2+4)
# Out:
# 15
# Cannot divided by zero
# 6

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
except ZeroDivisionError:
    print("Cannot divided by zero")
# Out:
# Enter num1:  2
# Enter num2:  0
# Cannot divided by zero

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    
except ZeroDivisionError:
    print("Cannot divided by zero")
    
except ValueError:
    print("Value Error")
# Out:
# Enter num1:  2
# Enter num2:  a
# Value Error

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    # print(result)
    
except ZeroDivisionError:
    print("Cannot divided by zero")
    
except ValueError:
    print("Value Error")

except TypeError:
    print("Type Error")

else:
    print(result)
# Out:
# Enter num1:  10
# Enter num2:  5
# 2.0

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    # print(result)
    
except ZeroDivisionError:
    print("Cannot divided by zero")
    
except ValueError:
    print("Value Error")

except TypeError:
    print("Type Error")

else:
    print(result)

finally:
    print("program executed")
# Out:
# Enter num1:  2
# Enter num2:  0
# Cannot divided by zero
# program executed

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    # print(result)
    
except ZeroDivisionError:
    print("Cannot divided by zero")
    
except ValueError:
    print("Value Error")

except TypeError:
    print("Type Error")

else:
    print(result)

finally:
    print("program executed")
# Out:
# Enter num1:  10
# Enter num2:  2
# 5.0
# program executed

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    # print(result)
    
except ZeroDivisionError:
    print("Cannot divided by zero")
    
except ValueError:
    print("Value Error")

except TypeError:
    print("Type Error")

else:
    print(result)

finally:
    print("program executed")
# Out:
# Enter num1:  2
# Enter num2:  abc
# Value Error
# program executed

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    # print(result)
    
except ZeroDivisionError:
    print("Cannot divided by zero")
    
except ValueError:
    print("Value Error")

except TypeError:
    print("Type Error")

else:
    print(result)

finally:
    print("program executed")
# Out:
# Enter num1:  2+3+4
# Value Error
# program executed

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    print(result)
    
except ZeroDivisionError:
    print("Cannot divided by zero")
# Out:
# Enter num1:  2
# Enter num2:  a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 try:
#       2     num1 = int(input("Enter num1: "))
# ----> 3     num2 = int(input("Enter num2: "))
#       4     result = num1/num2
#       5     print(result)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
try:
    num1 = int(input("Enter num1: "))
    num2 = int(input("Enter num2: "))
    result = num1/num2
    print(result)
    
# except ZeroDivisionError:
#     print("Cannot divided by zero")

except:
    print("Error")
# Out:
# Enter num1:  1
# Enter num2:  0
# Error

# %%
data = ["10", "20", "abc", "40"]

for value in data:
    try:
        number = int(value)

    except ValueError:
        print(f"Invalid value found: {value}")

    else:
        print(f"Valid number: {number}")

    finally:
        print("Checked one value\n")
# Out:
# Valid number: 10
# Checked one value
#
# Valid number: 20
# Checked one value
#
# Invalid value found: abc
# Checked one value
#
# Valid number: 40
# Checked one value

# %%
int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ## ***Object Oriented Programming (oop)***
# **Object Oriented Programming (OOP)** is a programming approach that organizes code into objects. These objects combine data (attributes) and functions (methods) into a single unit, based on real world entities.
#
# **Why We Use OOP:**
#
# **Modularity:** Breaks programs into smaller, reusable parts (classes and objects).
#
# **Reusability:** Code can be reused through inheritance.
#
# **Maintainability:** Easy to update and debug large programs.
#
# **Abstraction:** Hides unnecessary details, focusing on the essential.
#
# **Encapsulation:** Protects data by restricting access.

# %%
print(type("hello world"))
# Out:
# <class 'str'>

# %%
dir(" ")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
print(type([1,2,3]))
# Out:
# <class 'list'>

# %%
print(type((1,2,3)))
# Out:
# <class 'tuple'>

# %%
def greet():
        return "welcome"
        print("hello")

# %%
greet()
# Out:
# 'welcome'

# %%
def greet():
        print("hello")
        return "welcome"

# %%
greet()
# Out:
# hello
# 'welcome'

# %%
class Student:
    def greet():
        return "welcome"

# %%
stud = Student()

# %%
stud.greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 stud.greet()
#
# TypeError: Student.greet() takes 0 positional arguments but 1 was given

# %%
class Student:
    def greet(self):
        return "welcome"

# %%
stud = Student()
stud

# %%
stud.greet()
# Out:
# 'welcome'

# %%
class Student:
    def greet(self,name,age):
        return "welcome"

# %%
stud = Student()
stud

# %%
stud.greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 stud.greet()
#
# TypeError: Student.greet() missing 2 required positional arguments: 'name' and 'age'

# %%
stud.greet("khushboo",26)
# Out:
# 'welcome'

# %%
class Student:
    def greet(self,name,age):
        print(f'object: {self}')
        return "welcome"

# %%
stud = Student()

# %%
stud.greet("khushboo",26)
# Out:
# object: <__main__.Student object at 0x0000024503F07CB0>
# 'welcome'

# %%
class Student:
    def greet(self,name,age):
        self.stu_name = name
        self.stu_age = age
        return "welcome"

# %%
stud = Student()

# %%
stud.greet("khushboo",26)
# Out:
# 'welcome'

# %%
stud.stu_name
# Out:
# 'khushboo'

# %%
stud.stu_age
# Out:
# 26

# %%
dir(Student)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'greet']

# %%
class Student:
    def greet(self,name,age,Class):
        self.stu_name = name
        self.stu_age = age
        self.stu_class = Class
        return "welcome"

# %%
stu = Student()

# %%
stu

# %%
stu.greet("ali",40,14)
# Out:
# 'welcome'

# %%
stu.stu_class
# Out:
# 14

# %%
class Student:
    def greet(self,name,age,Class):
        self.stu_name = name
        self.stu_age = age
        self.stu_class = Class
        return "welcome"

    def sub(self):
        return "We are learning Oops"

# %%
stu = Student()
stu

# %%
stu.sub()
# Out:
# 'We are learning Oops'

# %%
class Student:
    def __init__(self,school_name,location,Class):
        self.school = school_name
        self.location = location
        return "hello"


    
    def greet(self,name,age,Class):
        self.stu_name = name
        self.stu_age = age
        self.stu_class = Class
        return "welcome"

    def sub(self):
        return "We are learning Oops"

# %%
Student("The karachi city","karachi",9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 Student("The karachi city","karachi",9)
#
# TypeError: __init__() should return None, not 'str'

# %%
class Student:
    def __init__(self,school_name,location,Class):
        self.school = school_name
        self.location = location
        print("hello")

    
    def greet(self,name,age,Class):
        self.stu_name = name
        self.stu_age = age
        self.stu_class = Class
        return "welcome"

    def sub(self):
        return "We are learning Oops"

# %%
stu = Student("The karachi city","karachi",9)
# Out:
# hello

# %%
stu.school
# Out:
# 'The karachi city'

# %%
stu.location
# Out:
# 'karachi'

# %%
dir(Student)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'greet',
#  'sub']

# %%
stu.sub()
# Out:
# 'We are learning Oops'

# %%
class Student:
    def __init__(self,school_name,location,Class):
        self.name = school_name
       

    
    def greet(self,name,age,Class):
        self.name = name
        
        return "welcome"

    def sub(self):
        return "We are learning Oops"

# %%
stu = Student("The karachi city","karachi",9)

# %%
stu.name
# Out:
# 'The karachi city'

# %%
stu.greet("khu",36,10)
# Out:
# 'welcome'

# %%
stu.name
# Out:
# 'khu'

# %%
stu.name
# Out:
# 'khu'

# %%
stu = Student("The karachi city","karachi",9)

# %%
stu.name
# Out:
# 'The karachi city'
